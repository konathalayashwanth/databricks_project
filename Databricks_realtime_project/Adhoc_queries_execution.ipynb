# %%
# %sql

drop table retail_chain_catalog.gold_schema.gold_loan_risk_exposure;

# %%
# %sql
select * from retail_chain_catalog.silver_schema.silver_accounts_cleaned;

# %%
# %sql

drop schema retail_chain_catalog.silver_schema cascade;
